# %%
import kerasAC 
from kerasAC.train import * 
inputs={"tiledb_tasks_file": "tasks.tsv",
        "chrom_sizes": /mnt/data/annotations/by_release/hg38/hg38.chrom.sizes \
    --train_chroms chr2 chr3 chr4 chr5 chr6 chr7 chr9 chr11 chr12 chr13 chr14 chr15 chr16 chr17 chr18 chr19 chr20 chr21 chr22 chrX chrY \
    --validation_chroms chr8 chr10 \
    --batch_size 20 \
    --label_source fc_bigwig \
                    --label_flank 1500 \
                    --label_aggregation None \
                    --sequence_flank 6500 \
		    --partition_attribute_for_upsample idr_peak \
		    --partition_thresh_for_upsample 2 \
		    --train_upsample 0.3 \
		    --valid_upsample 0 \
		    --num_train 10000 \
		    --num_valid 10000 \
		    --num_tasks 1 \
		    --threads 40 \
		    --max_queue_size 10 \
		    --patience 3 \
		    --patience_lr 2 \
		    --model_hdf5 ATAC.pseudobulk.ADPD.Cluster24.profile.0 \
		    --ref_fasta /mnt/data/annotations/by_release/hg38/GRCh38_no_alt_analysis_set_GCA_000001405.15.fasta \
		    --architecture_spec profile_model
# Out:
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
#
# Cluster24.idr.optimal.narrowPeak.chr1
# Cluster24.idr.optimal.narrowPeak.chr1.uniq
# .ipynb_checkpoints/
# KerasAC_Training_and_Prediction_with_TileDB.ipynb
# Microglia_Profile_Models_Split_0_Test_Chr1.ipynb
# microglia_single_cell_test_with_tiledb_gen.genomewide.sh
# microglia_single_cell_test_with_tiledb_gen.sh
# microglia_single_cell_test_with_tiledb_gen.summits.sh
# microglia_single_cell_train_with_tiledb_gen.sh
# sanity_check_tdb_inputs.ipynb
# Using TensorFlow backend.
# Traceback (most recent call last):
#   File "/users/annashch/miniconda3/bin/kerasAC_train", line 11, in <module>
#     load_entry_point('kerasAC', 'console_scripts', 'kerasAC_train')()
#   File "/users/annashch/kerasAC/kerasAC/train.py", line 263, in main
#     train(args)
#   File "/users/annashch/kerasAC/kerasAC/train.py", line 239, in train
#     train_generator,valid_generator=initialize_generators(args)
#   File "/users/annashch/kerasAC/kerasAC/train.py", line 203, in initialize_generators
#     return initialize_generators_tiledb(args)
#   File "/users/annashch/kerasAC/kerasAC/train.py", line 162, in initialize_generators_tiledb
#     label_transformer=args.label_transformer)
#   File "/users/annashch/kerasAC/kerasAC/tiledb_generators.py", line 63, in __init__
#     self.tasks=open(task_file,'r').read().strip().split('\n')
# FileNotFoundError: [Errno 2] No such file or directory: 'tasks.tsv'
# : 1
